# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('~/Desktop/Untitled.csv')

# %%
df
# Out:
#    camel  cloudstack  cocoon  deeplearning  hadoop  hive  node  ofbiz  qpid
# 0    2.9         5.4     3.8           3.0     2.9   3.2   1.9    2.5   3.3
# 1    3.8         3.0     2.9           3.2     1.9   2.5   3.3    2.9   5.4
# 2    2.9         3.2     1.9           2.5     3.3   2.9   5.4    3.8   3.0
# 3    1.9         2.5     3.3           2.9     5.4   3.8   3.0    2.9   3.2
# 4    3.3         2.9     5.4           3.8     3.0   2.9   3.2    1.9   2.5

# %%
plt.figure(dpi=150)
plt.xticks(rotation=45)
plt.ylabel('Intrinsic dimensionality')
sns.boxplot(data=df);
